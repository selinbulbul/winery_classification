# %% [markdown]
# # Importing tools

# %%
import pandas as pd 
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %%
# *data pre-processing* using sklearn
from sklearn.preprocessing import StandardScaler, LabelEncoder

from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
# model selection
from sklearn.ensemble import RandomForestClassifier

# metrics evaluation
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# # Data

# %%
WW_df = pd.read_csv('winequality-white.csv', delimiter = ';')

# %%
WW_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
WW_df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6

# %%
WW_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
sb.countplot(x = "quality", data = WW_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
WW_df["quality"].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
# categorizing quality type according to the quality of all the wine samples
WW_df["quality_type"] = WW_df["quality"].apply(lambda x : "Low" if x<=5 else "Medium" if x <= 6 else "High")

# %%
sb.countplot(x = "quality_type", data = WW_df)
# Out:
# <AxesSubplot:xlabel='quality_type', ylabel='count'>

# %%
WW_df["quality_type"].value_counts()
# Out:
# Medium    2198
# Low       1640
# High      1060
# Name: quality_type, dtype: int64

# %%
WW_df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality quality_type
# 0      8.8        6       Medium
# 1      9.5        6       Medium
# 2     10.1        6       Medium

# %% [markdown]
# ## Correlation Matrix

# %%
corr = WW_df.corr()

# %%
plt.figure(figsize = (12,8))
sb.heatmap(corr, linewidth = 5, cmap = "coolwarm", annot = True)
# Out:
# <AxesSubplot:>

# %%
sb.barplot(x="quality", y = "volatile acidity", data=WW_df, palette = "PuBu")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
sb.barplot(x="quality", y = "chlorides", data=WW_df, palette = "PuBu")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
sb.barplot(x = "quality", y = "total sulfur dioxide", data= WW_df, palette = "PuBu")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %% [markdown]
# ## Alcohol

# %%
sb.catplot(x = 'quality_type', y = 'alcohol', data = WW_df, order = ["Low", "Medium", "High"])

# %%
ww_df_2  = WW_df.groupby('quality').mean()
ww_df_2   [["alcohol"]]
# Out:
#            alcohol
# quality
# 3        10.345000
# 4        10.152454
# 5         9.808840
# 6        10.575372
# 7        11.367936
# 8        11.636000
# 9        12.180000

# %%
sb.barplot(x = "quality", y = "alcohol", data= WW_df, palette = "PuBu")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
plt.figure(figsize = (12,8))
sb.catplot(x = "quality", y = "alcohol", kind="box", data= WW_df) 
#sb.stripplot(x="quality", y="alcohol", color='black',data=WW_df)
plt.ylabel("Alcohol", size=10)
plt.xlabel("Quality", size=10)
plt.ylim(ymax = 15, ymin = 7.8)
plt.title("Alcohol Distribution in Different Quality", size=10)
# Out:
# Text(0.5, 1.0, 'Alcohol Distribution in Different Quality')

# %%
plt.figure(figsize=(4, 6))
sb.barplot(x= "quality_type", y="alcohol", data=WW_df, palette= ("BuGn"), order = ["Low", "Medium", "High"])
plt.ylabel("Alcohol % vol ", size=14)
plt.xlabel("Quality", size=14)
plt.ylim(ymax = 15, ymin = 0)
plt.title("Alcohol in White Wine", size=16)
#plt.savefig("Total sulfur dioxide.png")  #to save the figure
# Out:
# Text(0.5, 1.0, 'Alcohol in White Wine')

# %% [markdown]
# ### statistical tests- one way anova and t-test
